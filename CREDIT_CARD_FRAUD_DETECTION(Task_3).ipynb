# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayalakshmig1/CodSoft/blob/main/CREDIT_CARD_FRAUD_DETECTION(Task_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('creditcard.csv')
data
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0        0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2        1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3        1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4        2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 284612   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 284613   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 284614   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 284615   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 284616   NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#               V7        V8        V9  ...       V19       V20       V21  \
# ...

# %%
# Preprocess the data
data.fillna(method='ffill', inplace=True)
# Out:
# <ipython-input-3-3069d9bccddb>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Feature scaling
scaler = StandardScaler()
data[['V1', 'V2', 'V3']] = scaler.fit_transform(data[['V1', 'V2', 'V3']])

# %%
#split the dataset
X = data.drop(['Amount', 'Time'], axis=1)
y = data['Amount']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_train,X_test,y_train,y_test
# Out:
# (              V1        V2        V3        V4        V5        V6        V7  \
#  256834  0.005643 -0.001511  0.002212  1.289091 -0.735997  0.288069 -0.586057
#  69771   0.005643 -0.001511  0.002212  1.289091 -0.735997  0.288069 -0.586057
#  257328  0.005643 -0.001511  0.002212  1.289091 -0.735997  0.288069 -0.586057
#  131766  0.005643 -0.001511  0.002212  1.289091 -0.735997  0.288069 -0.586057
#  280961  0.005643 -0.001511  0.002212  1.289091 -0.735997  0.288069 -0.586057
#  ...          ...       ...       ...       ...       ...       ...       ...
#  119879  0.005643 -0.001511  0.002212  1.289091 -0.735997  0.288069 -0.586057
#  259178  0.005643 -0.001511  0.002212  1.289091 -0.735997  0.288069 -0.586057
#  131932  0.005643 -0.001511  0.002212  1.289091 -0.735997  0.288069 -0.586057
#  146867  0.005643 -0.001511  0.002212  1.289091 -0.735997  0.288069 -0.586057
#  121958  0.005643 -0.001511  0.002212  1.289091 -0.735997  0.288069 -0.586057
#
# ...

# %%
# Train the model
model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Evaluate the model
y_pred = model.predict(X_test)
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("R-squared:", r2_score(y_test, y_pred))
# Out:
# MAE: 0.0025246960968019288
# MSE: 0.14403367828624863
# R-squared: 0.6357434907770041

# %%
ThankYou!!!!!!!
